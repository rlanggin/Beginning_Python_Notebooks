# %% [markdown]
# # Notebook 09: Magnitude limits, panda tables, manipulating column names
# by Rachel Langgin \\
# March 2022 and July 2024 \\
# Haverford College and University of Nevada, Las Vegas \\

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
def function(x,y):
    z=x**y
    return(z)
z = function(2,3)
type(z)
# Out:
# int

# %%
# Point out the error in printing the following:
def function (m, n):
    m=3
    n=2
    p=(m*n)
    return(p)

# %%
function("hello", "goodbye")
# Out:
# 6

# %%
# What will the following code output?
months = ['january', 'february', 'march', 'april', 'may', 'june', 'july', 'august', 'september', 'october', 'november', 'december']
for month in months:
   if 'uary' in month:
       print(month)
   if 'er' in month:
       print(month)
# Out:
# january
# february
# september
# october
# november
# december

# %%
npmonths=np.array(months)
desind=np.where(npmonths == 'uary')

# %%
desind
# Out:
# (array([], dtype=int64),)

# %%
desind=np.where('uary' in npmonths)

# %%
desind
# Out:
# (array([], dtype=int64),)

# %%
import pandas as pd
data = [['tom', 10], ['nick', 15], ['juli', 14]]
df = pd.DataFrame(data, columns = ['Name', 'Age'])  # Make a pandas dataframe called df,
# give it column names Name and Age
for i in range(3):
    print("%s is %d years old." %(df.iloc[i].Name, df.iloc[i].Age))
# What is wrong here?
# Out:
# tom is 10 years old.
# nick is 15 years old.
# juli is 14 years old.

# %% [markdown]
# ## A few fun things with pandas
#
# To get the next cell to work you need to download "netflix_titles.csv" from the same folder where you got this ipynb file. Then upload it to your Jupyter hub.

# %%
from google.colab import drive
#drive.mount("/content/drive") # this line only has to be run once
mytable=pd.read_csv('/content/drive/MyDrive/UNLV/research!/projects/GW_Explorer_A_Beginners_Guide/Beginning_Python_Notebooks/netflix_titles.csv', delimiter=',')
mytable
# Out:
#      show_id     type                                    title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7782   s7783    Movie                                     Zozo
# 7783   s7784    Movie                                   Zubaan
# 7784   s7785    Movie                        Zulu Man in Japan
# 7785   s7786  TV Show                    Zumbo's Just Desserts
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %% [markdown]
# ### Here's how to look at the column names

# %%
mytable.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
mytable.columns=['show_id', 'Andrea', 'title', 'director', 'cast', 'country', 'date_added',
       'release_year', 'rating', 'duration', 'listed_in', 'description']

# %%
mytable
# Out:
#      show_id   Andrea                                        title  \
# 0         s1  TV Show                                           3%
# 1         s2    Movie                                         7:19
# 2         s3    Movie                                        23:59
# 3         s4    Movie                                            9
# 4         s5    Movie                                           21
# 5         s6  TV Show                                           46
# 6         s7    Movie                                          122
# 7         s8    Movie                                          187
# 8         s9    Movie                                          706
# 9        s10    Movie                                         1920
# 10       s11    Movie                                         1922
# 11       s12  TV Show                                         1983
# 12       s13  TV Show                                         1994
# ...

# %% [markdown]
# This table has pretty nice column names, but sometimes they're horrible.  I just want to show you how to rename the columns if you want to.

# %%
mytable.columns = ['show_id', 'Andrea', 'title', 'director', 'cast', 'country', 'date_added',
       'release_year', 'rating', 'duration', 'listed_in', 'description']

# %% [markdown]
# ## For your projects, some of you will have data with words in it, like above.
# I want to show you the power of pandas.
#
# First, I don't actually try to memorize all the stuff pandas can do.  I look it up.  Next week we'll talk about looking things up on the web.  Here's where I learned the following:
#
#
# https://stackoverflow.com/questions/11350770/select-by-partial-string-from-a-pandas-dataframe

# %%
len(mytable[mytable['cast'].str.contains("Tom", na=False)])
# Out:
# 357

# %% [markdown]
# ## Assignment: Experiment with that on whatever data set you want from the google.
#
# Here's a list of  10 sites where you can get data (there are many more sites than this.) https://www.dataquest.io/blog/free-datasets-for-projects/  Just make sure you get the "csv" (comma separated values)
