# %% [markdown]
# # Introduction to Python: for Physics and Astronomy
# by Rachel Langgin \\
# March 2022 and July 2024 \\
# Haverford College and University of Nevada, Las Vegas \\
#
# This notebook series is designed to introduce simple coding concepts with the theme for Physics and Astronomy introductory students. At a glance, these notebooks will serve as a place to practice code for anywho who has never coded in Python before. As the notebooks progress, we will begin to dive into how these computational tools can be applied to analyze rich astronomical datasets and further advanced coding practices.

# %% [markdown]
# Let's begin by assigning a number to a variable:

# %%
x=1

# %%
x
# Out:
# 1

# %%
x=x+1

# %%
x
# Out:
# 2

# %%
x=x+17

# %%
x
# Out:
# 19

# %% [markdown]
# # Great! The computer stores the variable's information and can compute simple mathematics. Let's try using a "print" statement.

# %%
print(x)
# Out:
# 19

# %% [markdown]
# # We can see that Python has now stored the last called information for x, which is now 19. If you rerun cell 1 and reset the variable x back to 1, then run the above print statement, you will see it change back to 1.

# %%
print("Your Name")
# Out:
# Your Name

# %% [markdown]
# We can also print letters! Python stores letters and numbers in different formats called "strings" or "floats", respectively. All strings (letters) must be contained within quotation marks. Also, the print statement only works with parenthesis. This is a special feature of the built-in Python function "print". We'll discuss this more later, but it is is important to distinguish the format when using different code.

# %%
print("The number of people in this room is", x)
# Out:
# The number of people in this room is 19

# %% [markdown]
# We can also utilize Python's memory by printing both the string with the varible x.

# %%
# We can break apart a print statement by using commas:
# Putting a hashtag infront of a line will "comment out" the line so you can write notes/comments here!
print("The number of people in this room is", x, ".")
# Out:
# The number of people in this room is 19 .

# %% [markdown]
# Fancy (and annoying but useful) version: print(”The number of apples in the bin is {}“.format(x)):
#
# The fancy brackets act as placeholders.

# %% [markdown]
# # Print statements in various ways:

# %%
print('The number of apples in the bin is {}. And if I add one to that number I get {}.'.format(x, x+1))
# Out:
# The number of apples in the bin is 19. And if I add one to that number I get 20.

# %%
print("hello")
# Out:
# hello

# %%
print("I would like {} apples, {} pears, and {} bananas.".format(3,5,7))
# Out:
# I would like 3 apples, 5 pears, and 7 bananas.

# %% [markdown]
# # Experimenting with "if" statement. Another built-in Python function.

# %%
x=1 #Assiging the number 1 to x

# %%
if(x==1):     # The double equal sign is the comparison operator
    print("hello") # we only want to say hello if x=1
# Out:
# hello

# %%
if(x==0):
    print("hello")
print("andrea")
print("snow")
# Out:
# andrea
# snow

# %%
print(4==4)
# Out:
# True

# %%
x
# Out:
# 1

# %%
if (x==1): print("hello")
# Out:
# hello

# %%
howmuch=[5,7,9]
fruits=["apples", "bananas", "pears"]
print(howmuch)
# Out:
# [5, 7, 9]

# %%
print(fruits)
# Out:
# ['apples', 'bananas', 'pears']

# %%
fruits[1]
# Out:
# 'bananas'

# %%
fruits[0]
# Out:
# 'apples'

# %%
print(fruits[0]) # This needs square brackets.
# Out:
# apples

# %%
print(howmuch(2)) # if you use parentheses instead of brackets it doesn't work!
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-e4ae9d0f37b6> in <module>()
# ----> 1 print(howmuch(2))
#
# TypeError: 'list' object is not callable
